# %%
#instalação do tabula-py e importação dos pacotes pandas e numpy
# !pip install tabula-py
import tabula
import pandas as pd
import numpy as np
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 85.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 62.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 61.7 MB/s eta 0:00:00
# ...

# %%
import pdfplumber

# Abrir o arquivo PDF com pdfplumber
with pdfplumber.open("/content/[82i]-57821532_Nota Técnica BLOCO 2 - NT AG 009 - BENS REVERSÍVEIS.pdf") as pdf:
    todas_paginas = []

    # Definir o intervalo de páginas que deseja extrair (páginas 8 a 27)
    for i in range(7, 27):  # pdfplumber usa índices baseados em zero (página 8 = índice 7)
        pagina = pdf.pages[i]

        # Extrair tabela da página
        tabela = pagina.extract_table()

        # Converter tabela em DataFrame
        df_pagina = pd.DataFrame(tabela)

        if i == 7:
            # Usar a primeira linha da página 8 como cabeçalho
            df_pagina.columns = df_pagina.iloc[0]  # Definir o cabeçalho
            df_pagina = df_pagina[1:]  # Remover a linha que virou cabeçalho
        else:
            # Usar as mesmas colunas da página 8 para as demais páginas
            df_pagina.columns = todas_paginas[0].columns

        # Adicionar a página processada à lista
        todas_paginas.append(df_pagina)

# Concatenar todas as páginas
df_final = pd.concat(todas_paginas, ignore_index=True)

# %%
# Exibir o dataframe final
df_final
# Out:
# 0                     Descrição (Equipamento / Unidade)  \
# 0     Moto bomba centrífuga monoestágio - 5 cv - 220...
# 1     Painel Elétrico de comando 220 Vca - A400xL300...
# 2      Painel operante em bom estado de partida direta.
# 3     Moto bomba centrífuga multiestágios - 5Cv - 22...
# 4     Painel Elétrico do sistema de lavagem dos filt...
# ...                                                 ...
# 1905                                UT (ETA) Rio Grande
# 1906                                        UT Sacarrão
# 1907                VENTOSA EFLUENTES TRIP FUNCAO D25 5
# 1908                        PAINEL ELET 2 X 10 CV /480V
# 1909                     PAINEL ELET 4 X 50 CV CV /220V
#
# 0                           Descrição da Unidade        Município
# 0                           Booster do Eucalipto  Paty do Alferes
# 1           ETA Conrado (Inclusive Reservatório)   Miguel Pereira
# 2                                    EEAT Italva   Rio de Janeiro
# ...

# %%
#exportar para excel

df_final.to_excel('df1.xlsx', index=False)
