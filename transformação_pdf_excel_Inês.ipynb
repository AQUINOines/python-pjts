# %%
#instalação do tabula-py e importação dos pacotes pandas e numpy
# !pip install tabula-py
import tabula
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: tabula-py in /usr/local/lib/python3.10/dist-packages (2.9.3)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.26.4)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)

# %%
#importar arquivo pdf para transformar em dataframe

df = tabula.read_pdf('/content/2º RELATORIO ANEXO I - AGUA.pdf', pages='all')
# Out:
# WARNING:tabula.backend:Failed to import jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'
# WARNING:tabula.backend:Got stderr: Oct 16, 2024 7:29:22 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Oct 16, 2024 7:29:22 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Oct 16, 2024 7:29:22 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Oct 16, 2024 7:29:22 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Oct 16, 2024 7:29:22 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
#importar arquivo em pdf via pandas

df1 = pd.concat(df).reset_index(drop=True)
# Out:
#   CENTRO CUSTOPLAQUETA\rMUNICIPIOBAIRROOPERAÇAODESCRIÇÃOMARCAMODELONo SÉRIECLASSEFVAVALOR DE REPOSIÇÃOVALOR ATUALVUR\rNOVA  \
# 0                                     RIO DE JANEIRO
# 1                                     RIO DE JANEIRO
# 2                                     RIO DE JANEIRO
# 3                                     RIO DE JANEIRO
# 4                                     RIO DE JANEIRO
#
#        Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0  TIJUCA / MEIER       AGUA  ETA (OMQ)      17.693
# 1  TIJUCA / MEIER       AGUA  ETA (OMQ)      17.696
# 2  TIJUCA / MEIER       AGUA  ETA (OMQ)      17.688
# 3  TIJUCA / MEIER       AGUA  ETA (OMQ)      17.692
# 4  TIJUCA / MEIER       AGUA  ETA (OMQ)      17.691
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0              BOMBA DOSADORA HIPOCLORITO    ETATRON        NaN        NaN
# 1                      MOTO BOMBA 0,75 CV        WEG        NaN        NaN
# 2           CADEIRA FIXA MADEIRA S/ BRACO        NaN        NaN        NaN
# 3           CADEIRA FIXA MADEIRA S/ BRACO        NaN        NaN        NaN
# 4  FONTE ALIMENTACAO P/ RADIO TRANSCEPTOR        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  Unnamed: 12
# 0        M E       0,60    R$890,00   R$5 34,00          6.0
# 1        M E       0,60    R$125,00     R$75,00          6.0
# 2        M U       0,45    R$4 3,00     R$19,35          5.0
# 3        M U       0,45    R$4 3,00     R$19,35          5.0
# 4        M U       0,60    R$9 5,00     R$57,00          6.0

# %%
#nomear as colunas de acordo

df1.columns = ['municipio', 'bairro', 'operacao', 'centro_custo', 'plaq_nova','descricao', 'marca', 'modelo', 'n_serie', 'classe', 'fva', 'valor_reposicao', 'valor_atual', 'vur']

# %%
df1.head(10)
# Out:
#         municipio          bairro operacao centro_custo  plaq_nova  \
# 0  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.693
# 1  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.696
# 2  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.688
# 3  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.692
# 4  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.691
# 5  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.694
# 6  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.695
# 7  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.689
# 8  RIO DE JANEIRO  TIJUCA / MEIER     AGUA    ETA (OMQ)     17.690
# 9  RIO DE JANEIRO  TIJUCA / MEIER     AGUA          SCQ     15.558
#
#                                  descricao       marca   modelo n_serie  \
# 0               BOMBA DOSADORA HIPOCLORITO     ETATRON      NaN     NaN
# 1                       MOTO BOMBA 0,75 CV         WEG      NaN     NaN
# 2            CADEIRA FIXA MADEIRA S/ BRACO         NaN      NaN     NaN
# 3            CADEIRA FIXA MADEIRA S/ BRACO         NaN      NaN     NaN
# 4   FONTE ALIMENTACAO P/ RADIO TRANSCEPTOR         NaN      NaN     NaN
# 5                        FONTE DE CORRENTE  HIDROGERON  HG PLUS  3799.0
# 6                        FONTE DE CORRENTE  HIDROGERON  HG PLUS     NaN
# 7  MESA MADEIRA P/ TELEFONE 0,40X0,40X0,68         NaN      NaN     NaN
# 8            RADIO TRANSCEPTOR C/ 4 CANAIS     CONTROL  GRD 040     NaN
# 9                       IMPRESSORA DESKJET          HP    656 C     NaN
#
#   classe   fva valor_reposicao valor_atual  vur
# 0    M E  0,60        R$890,00   R$5 34,00  6.0
# 1    M E  0,60        R$125,00     R$75,00  6.0
# 2    M U  0,45        R$4 3,00     R$19,35  5.0
# 3    M U  0,45        R$4 3,00     R$19,35  5.0
# 4    M U  0,60        R$9 5,00     R$57,00  6.0
# 5    M U  0,60        R$9 5,00     R$57,00  6.0
# 6    M U  0,60        R$9 5,00     R$57,00  6.0
# 7    M U  0,30        R$148,00     R$44,40  3.0
# 8    M U  0,45        R$880,00   R$3 96,00  5.0
# 9    C P  0,60        R$328,00   R$1 96,80  3.0

# %%
#exportar para excel

df1.to_excel('df1.xlsx', index=False)
